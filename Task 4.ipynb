# %% [markdown]
# 模型评估

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.model_selection import cross_val_predict

# %%
y_train_lg = lg.predict(X_train)
y_train_svm = svm_clf.predict(X_train)
y_train_dt = dt_clf.predict(X_train)
y_train_Rf = Rf.predict(X_train)
#y_train_xgb = xgb_clf.predict(X_train)

y_test_lg = lg.predict(X_test)
y_test_svm = svm_clf.predict(X_test)
y_test_dt = dt_clf.predict(X_test)
y_test_Rf = Rf.predict(X_test)
#y_test_xgb = xgb_clf.predict(x_test)

# %%
y_list = ['y_train_lg', 'y_train_svm', 'y_train_dt', 'y_train_Rf']
print('accuracy score on train data of models: ')
print(accuracy_score(y_train,y_train_lg))
print(accuracy_score(y_train,y_train_svm))
print(accuracy_score(y_train,y_train_dt))
print(accuracy_score(y_train,y_train_Rf))

print('\n')
print('accuracy score on test data of models: ')
print(accuracy_score(y_test,y_test_lg))
print(accuracy_score(y_test,y_test_svm))
print(accuracy_score(y_test,y_test_dt))
print(accuracy_score(y_test,y_test_Rf))

print('\n')
print('precision on train data: ')
print(precision_score(y_train,y_train_lg))
print(precision_score(y_train,y_train_svm))
print(precision_score(y_train,y_train_dt))
print(precision_score(y_train,y_train_Rf))

print('\n')
print('precision on test data: ')
print(precision_score(y_test,y_test_lg))
print(precision_score(y_test,y_test_svm))
print(precision_score(y_test,y_test_dt))
print(precision_score(y_test,y_test_Rf))

print('\n')
print('recall - train:')
print(recall_score(y_train,y_train_lg))
print(recall_score(y_train,y_train_svm))
print(recall_score(y_train,y_train_dt))
print(recall_score(y_train,y_train_Rf))

print('\n')
print('recall - test:')
print(recall_score(y_test,y_test_lg))
print(recall_score(y_test,y_test_svm))
print(recall_score(y_test,y_test_dt))
print(recall_score(y_test,y_test_Rf))

print('\n')
print('f1-score - train:')
print(f1_score(y_train,y_train_lg))
print(f1_score(y_train,y_train_svm))
print(f1_score(y_train,y_train_dt))
print(f1_score(y_train,y_train_Rf))

print('\n')
print('f1-score - test:')
print(f1_score(y_test,y_test_lg))
print(f1_score(y_test,y_test_svm))
print(f1_score(y_test,y_test_dt))
print(f1_score(y_test,y_test_Rf))

print('\n')
print('AUC - train:')
print(roc_auc_score(y_train,y_train_lg))
print(roc_auc_score(y_train,y_train_svm))
print(roc_auc_score(y_train,y_train_dt))
print(roc_auc_score(y_train,y_train_Rf))

print('\n')
print('AUC - test:')
print(roc_auc_score(y_test,y_test_lg))
print(roc_auc_score(y_test,y_test_svm))
print(roc_auc_score(y_test,y_test_dt))
print(roc_auc_score(y_test,y_test_Rf))
# Out:
# accuracy score on train data of models:
# 0.7571385632702134
# 1.0
# 1.0
# 0.97956116621581
#
#
# accuracy score on test data of models:
# 0.7302032235459005
# 0.7302032235459005
# 0.6790469516468115
# 0.764540995094604
#
#
# precision on train data:
# 0.0
# 1.0
# 1.0
# 0.9959785522788204
#
#
# precision on test data:
# 0.0
# 0.0
# 0.40852130325814534
# 0.6560509554140127
#
#
# recall - train:
# 0.0
# 1.0
# 1.0
# 0.9195544554455446
#
#
# recall - test:
# 0.0
# 0.0
# 0.42337662337662335
# 0.2675324675324675
#
#
# f1-score - train:
# 0.0
# 1.0
# 1.0
# 0.9562419562419562
#
#
# f1-score - test:
# 0.0
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
#做得不太对_(:зゝ∠)_
